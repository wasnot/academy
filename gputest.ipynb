# %%
import theano

# %%
from theano import function, config, shared, tensor, sandbox
import numpy
import time

vlen = 10 * 30 * 768  # 10 x #cores x # threads per core
iters = 1000
rng = numpy.random.RandomState(22)
x = shared(numpy.asarray(rng.rand(vlen), config.floatX))
f = function([], tensor.exp(x))
print(f.maker.fgraph.toposort())
t0 = time.time()


for i in range(iters):
    r = f()
t1 = time.time()
print("Looping %d times took %f seconds" % (iters, t1 - t0))
print("Result is %s" % (r,))
if numpy.any([isinstance(x.op, tensor.Elemwise) and
    ('Gpu' not in type(x.op).__name__)
    for x in f.maker.fgraph.toposort()]):
    print('Used the cpu')
else:
    print('Used the gpu')
# Out:
# [Elemwise{exp,no_inplace}(<TensorType(float64, vector)>)]
# Looping 1000 times took 1.463980 seconds
# Result is [ 1.23178032  1.61879341  1.52278065 ...,  2.20771815  2.29967753
#   1.62323285]
# Used the cpu

# %%
import pygpu

# %%
pygpu.test()
# Out:
# pygpu is installed in /Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/pygpu
# NumPy version 1.11.3
# NumPy relaxed strides checking option: False
# NumPy is installed in /Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/numpy
# Python version 3.6.1 |Anaconda custom (x86_64)| (default, May 11 2017, 13:04:09) [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
# nose version 1.3.7
# EEEEEEE
# ======================================================================
# ERROR: Failure: RuntimeError (No test device specified.  Specify one using the DEVICE or GPUARRAY_TEST_DEVICE environment variables.)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/nose/failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/nose/loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/nose/importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/nose/importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/imp.py", line 234, in load_module
#     return load_source(name, filename, file)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 675, in _load
#   File "<frozen importlib._bootstrap>", line 655, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 205, in _call_with_frames_removed
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/pygpu/tests/test_basic.py", line 5, in <module>
#     from .support import (gen_gpuarray, context)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/pygpu/tests/support.py", line 32, in <module>
#     context = gpuarray.init(get_env_dev())
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/pygpu/tests/support.py", line 29, in get_env_dev
#     raise RuntimeError("No test device specified.  Specify one using the DEVICE or GPUARRAY_TEST_DEVICE environment variables.")
# RuntimeError: No test device specified.  Specify one using the DEVICE or GPUARRAY_TEST_DEVICE environment variables.
#
# ======================================================================
# ERROR: Failure: RuntimeError (No test device specified.  Specify one using the DEVICE or GPUARRAY_TEST_DEVICE environment variables.)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/nose/failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/nose/loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/nose/importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/nose/importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/imp.py", line 234, in load_module
#     return load_source(name, filename, file)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 675, in _load
#   File "<frozen importlib._bootstrap>", line 655, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 205, in _call_with_frames_removed
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/pygpu/tests/test_blas.py", line 5, in <module>
#     from .support import (guard_devsup, gen_gpuarray, context)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/pygpu/tests/support.py", line 32, in <module>
#     context = gpuarray.init(get_env_dev())
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/pygpu/tests/support.py", line 29, in get_env_dev
#     raise RuntimeError("No test device specified.  Specify one using the DEVICE or GPUARRAY_TEST_DEVICE environment variables.")
# RuntimeError: No test device specified.  Specify one using the DEVICE or GPUARRAY_TEST_DEVICE environment variables.
#
# ======================================================================
# ERROR: Failure: RuntimeError (No test device specified.  Specify one using the DEVICE or GPUARRAY_TEST_DEVICE environment variables.)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/nose/failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/nose/loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/nose/importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/nose/importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/imp.py", line 234, in load_module
#     return load_source(name, filename, file)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 675, in _load
#   File "<frozen importlib._bootstrap>", line 655, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 205, in _call_with_frames_removed
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/pygpu/tests/test_elemwise.py", line 13, in <module>
#     from .support import (guard_devsup, context, gen_gpuarray, check_meta_content)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/pygpu/tests/support.py", line 32, in <module>
#     context = gpuarray.init(get_env_dev())
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/pygpu/tests/support.py", line 29, in get_env_dev
#     raise RuntimeError("No test device specified.  Specify one using the DEVICE or GPUARRAY_TEST_DEVICE environment variables.")
# RuntimeError: No test device specified.  Specify one using the DEVICE or GPUARRAY_TEST_DEVICE environment variables.
#
# ======================================================================
# ERROR: Failure: RuntimeError (No test device specified.  Specify one using the DEVICE or GPUARRAY_TEST_DEVICE environment variables.)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/nose/failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/nose/loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/nose/importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/nose/importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/imp.py", line 234, in load_module
#     return load_source(name, filename, file)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 675, in _load
#   File "<frozen importlib._bootstrap>", line 655, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 205, in _call_with_frames_removed
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/pygpu/tests/test_gpu_ndarray.py", line 15, in <module>
#     from .support import (guard_devsup, check_meta, check_flags, check_all,
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/pygpu/tests/support.py", line 32, in <module>
#     context = gpuarray.init(get_env_dev())
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/pygpu/tests/support.py", line 29, in get_env_dev
#     raise RuntimeError("No test device specified.  Specify one using the DEVICE or GPUARRAY_TEST_DEVICE environment variables.")
# RuntimeError: No test device specified.  Specify one using the DEVICE or GPUARRAY_TEST_DEVICE environment variables.
#
# ======================================================================
# ERROR: Failure: RuntimeError (No test device specified.  Specify one using the DEVICE or GPUARRAY_TEST_DEVICE environment variables.)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/nose/failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/nose/loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/nose/importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/nose/importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/imp.py", line 234, in load_module
#     return load_source(name, filename, file)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 675, in _load
#   File "<frozen importlib._bootstrap>", line 655, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 205, in _call_with_frames_removed
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/pygpu/tests/test_operations.py", line 4, in <module>
#     from .support import (gen_gpuarray, context, SkipTest)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/pygpu/tests/support.py", line 32, in <module>
#     context = gpuarray.init(get_env_dev())
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/pygpu/tests/support.py", line 29, in get_env_dev
#     raise RuntimeError("No test device specified.  Specify one using the DEVICE or GPUARRAY_TEST_DEVICE environment variables.")
# RuntimeError: No test device specified.  Specify one using the DEVICE or GPUARRAY_TEST_DEVICE environment variables.
#
# ======================================================================
# ERROR: Failure: RuntimeError (No test device specified.  Specify one using the DEVICE or GPUARRAY_TEST_DEVICE environment variables.)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/nose/failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/nose/loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/nose/importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/nose/importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/imp.py", line 234, in load_module
#     return load_source(name, filename, file)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 675, in _load
#   File "<frozen importlib._bootstrap>", line 655, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 205, in _call_with_frames_removed
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/pygpu/tests/test_reduction.py", line 8, in <module>
#     from .support import (guard_devsup, check_meta_content, context, gen_gpuarray,
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/pygpu/tests/support.py", line 32, in <module>
#     context = gpuarray.init(get_env_dev())
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/pygpu/tests/support.py", line 29, in get_env_dev
#     raise RuntimeError("No test device specified.  Specify one using the DEVICE or GPUARRAY_TEST_DEVICE environment variables.")
# RuntimeError: No test device specified.  Specify one using the DEVICE or GPUARRAY_TEST_DEVICE environment variables.
#
# ======================================================================
# ERROR: Failure: RuntimeError (No test device specified.  Specify one using the DEVICE or GPUARRAY_TEST_DEVICE environment variables.)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/nose/failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/nose/loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/nose/importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/nose/importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/imp.py", line 234, in load_module
#     return load_source(name, filename, file)
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 675, in _load
#   File "<frozen importlib._bootstrap>", line 655, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 205, in _call_with_frames_removed
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/pygpu/tests/test_tools.py", line 5, in <module>
#     from .support import (guard_devsup, rand, check_flags, check_meta, check_all,
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/pygpu/tests/support.py", line 32, in <module>
#     context = gpuarray.init(get_env_dev())
#   File "/Users/akihiroaida/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/pygpu/tests/support.py", line 29, in get_env_dev
#     raise RuntimeError("No test device specified.  Specify one using the DEVICE or GPUARRAY_TEST_DEVICE environment variables.")
# RuntimeError: No test device specified.  Specify one using the DEVICE or GPUARRAY_TEST_DEVICE environment variables.
#
# ----------------------------------------------------------------------
# Ran 7 tests in 0.005s
#
# FAILED (errors=7)
